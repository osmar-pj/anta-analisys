# %%
df.head(1)
# Out:
#    parkingDuration  tripDuration      ratio                   trip tripFrom  \
# 0             1.58          2.13  49.963636  STK3 - REFERENCE_PALA     STK3
#
#            tripTo       datetimeBegin         datetimeEnd  mileage  \
# 0  REFERENCE_PALA 2022-06-01 00:14:28 2022-06-01 02:22:04    11.44
#
#   tripDurationTime parkingDurationTime  avgSpeed  maxSpeed  consumed  \
# 0          2:07:36             1:35:02       5.0      37.0     27.48
#
#    avgConsumed  timestampBegin  timestampEnd       nm            eq
# 0         0.42      1654060468    1654068124  CAM-101  sin hidragen

# %%
df1 = df.query('tripFrom == "REFERENCE_PALA"')

# %%
sns.relplot(data=df1, x='mileage', y='consumed', hue='trip', col='nm')

# %%
sns.relplot(data=df1, x='avgSpeed', y='ratio', hue='trip', col='nm')

# %%
sns.relplot(data=df1, x='avgSpeed', y='ratio', hue='trip', col='eq')

# %%
sns.relplot(data=df1, x='avgSpeed', y='ratio', hue='nm', col='eq')

# %%
df2 = df.query('nm == "CAM121"')

# %%
sns.relplot(data=df1, x='avgSpeed', y='ratio', hue='eq', col='trip')

# %%
sns.relplot(data=df1, x='mileage', y='consumed', hue='eq', col='trip')

# %%
df3 = df.query('tripFrom == "CHANCADO I"')

# %%
df4 = df.query('nm == "CAM121"')

# %%
df3.head(10)
# Out:
#     parkingDuration  tripDuration       ratio                         trip  \
# 2              0.00          0.12    6.833333  CHANCADO I - REFERENCE_PALA
# 7              0.00          0.12    4.750000  CHANCADO I - REFERENCE_PALA
# 9              0.00          0.27   22.000000  CHANCADO I - REFERENCE_PALA
# 33             0.33          0.52  134.842105             CHANCADO I - 992
# 43             0.00          0.08   12.750000            CHANCADO I - LT03
# 49             0.00          0.12   11.416667  CHANCADO I - REFERENCE_PALA
# 64             0.00          0.12    4.416667  CHANCADO I - REFERENCE_PALA
# 69             0.00          0.07    9.857143            CHANCADO I - STK5
# 74             0.00          0.09   12.777778  CHANCADO I - REFERENCE_PALA
# 80             0.00          0.12    7.166667  CHANCADO I - REFERENCE_PALA
#
#       tripFrom          tripTo       datetimeBegin         datetimeEnd  \
# ...

# %%
df4 = df3.query('nm == "CAM-121"')

# %%
sns.relplot(data=df4, x='avgSpeed', y='ratio', hue='eq', col='trip')

# %%
sns.relplot(data=df4, x='mileage', y='consumed', hue='eq', col='trip')
